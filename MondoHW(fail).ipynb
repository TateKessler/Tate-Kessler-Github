# %% [markdown]
# <a href="https://colab.research.google.com/github/TateKessler/Tate-Kessler-Github/blob/main/MondoHW(fail).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pymongo certifi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.0 MB/s eta 0:00:00
# ...

# %%
# Install pymongo for MongoDB connection


# Import necessary libraries
from pymongo import MongoClient
import pprint

# Replace with your MongoDB Atlas connection string
connection_string = "mongodb+srv://tkessler0012:<TatedbPassword>@hwdb.bvai8.mongodb.net/?retryWrites=true&w=majority&appName=HWDB"

# Connect to MongoDB Atlas
client = MongoClient(connection_string)

# Access the sample_mflix database and the movies collection
db = client['sample_mflix']
collection = db['movies']

# %%
query = {"genres": "Action"}
movie = collection.find_one(query)

pprint.pprint(movie)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-6-119bbe1054c5> in <cell line: 4>()
#       2
#       3 query = {"genres": "Action"}
# ----> 4 movie = collection.find_one(query)
#       5
#       6 pprint.pprint(movie)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/collection.py in find_one(self, filter, *args, **kwargs)
#    1728             filter = {"_id": filter}
#    1729         cursor = self.find(filter, *args, **kwargs)
# -> 1730         for result in cursor.limit(-1):
#    1731             return result
#    1732         return None
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1279
#    1280     def __next__(self) -> _DocumentType:
# -> 1281         return self.next()
#    1282
#    1283     def __iter__(self) -> Cursor[_DocumentType]:
#
# ...

# %% [markdown]
# Could not find a way to rectify this

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://tkessler0012:<TatedbPassword>@hwdb.bvai8.mongodb.net/?retryWrites=true&w=majority&appName=HWDB"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# SSL handshake failed: hwdb-shard-00-01.bvai8.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: hwdb-shard-00-00.bvai8.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: hwdb-shard-00-02.bvai8.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1007) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 67031667bd2bb67eeddc8603, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('hwdb-shard-00-00.bvai8.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: hwdb-shard-00-00.bvai8.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_
# ...

# %%
query = {"genres": "Action"}
movie = collection.find_one(query)

pprint.pprint(movie)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-3-119bbe1054c5> in <cell line: 4>()
#       2
#       3 query = {"genres": "Action"}
# ----> 4 movie = collection.find_one(query)
#       5
#       6 pprint.pprint(movie)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/collection.py in find_one(self, filter, *args, **kwargs)
#    1728             filter = {"_id": filter}
#    1729         cursor = self.find(filter, *args, **kwargs)
# -> 1730         for result in cursor.limit(-1):
#    1731             return result
#    1732         return None
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1279
#    1280     def __next__(self) -> _DocumentType:
# -> 1281         return self.next()
#    1282
#    1283     def __iter__(self) -> Cursor[_DocumentType]:
#
# ...

# %% [markdown]
# Same message and I couldnt fix it

# %% [markdown]
# This was the culmination of over two hours of work. I tried to look through the Mongo Connection instructions and the methods from the practice notebook but could never successfully connect with the database. I am submitting this because I dont want it to appear as missing.

# %%
uri = "mongodb+srv://tkessler0012:<TatedbPassword>@cluster0.bvai8.mongodb.net/?retryWrites=true&w=majority&ssl=false"
client = MongoClient(uri, server_api=ServerApi('1'))
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-8-257755b8f54f> in <cell line: 2>()
#       1 uri = "mongodb+srv://tkessler0012:<TatedbPassword>@cluster0.bvai8.mongodb.net/?retryWrites=true&w=majority&ssl=false"
# ----> 2 client = MongoClient(uri, server_api=ServerApi('1'))
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     778                         keyword_opts.cased_key("connecttimeoutms"), timeout
#     779                     )
# --> 780                 res = uri_parser.parse_uri(
#     781                     entity,
#     782                     port,
#
# /usr/local/lib/python3.10/dist-packages/pymongo/uri_parser.py in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
# ...

# %% [markdown]
# Attempt 3 using Atlas Starter Python from mongodb-university

# %%
import pymongo
import sys

# %%
try:
  client = pymongo.MongoClient("mongodb+srv://tkessler0012:<TatedbPassword>@hwdb.bvai8.mongodb.net/?retryWrites=true&w=majority&appName=HWDB")

# return a friendly error if a URI error is thrown
except pymongo.errors.ConfigurationError:
  print("An Invalid URI host error was received. Is your Atlas host name correct in your connection string?")
  sys.exit(1)

# %%
db = client['sample_mflix']
collection = db['movies']

# %%
query = {"genres": "Action"}
movie = collection.find_one(query)

pprint.pprint(movie)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-13-f8928749dc5b> in <cell line: 2>()
#       1 query = {"genres": "Action"}
# ----> 2 movie = collection.find_one(query)
#       3
#       4 pprint.pprint(movie)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/collection.py in find_one(self, filter, *args, **kwargs)
#    1728             filter = {"_id": filter}
#    1729         cursor = self.find(filter, *args, **kwargs)
# -> 1730         for result in cursor.limit(-1):
#    1731             return result
#    1732         return None
#
# /usr/local/lib/python3.10/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1279
#    1280     def __next__(self) -> _DocumentType:
# -> 1281         return self.next()
#    1282
#    1283     def __iter__(self) -> Cursor[_DocumentType]:
#
# ...
